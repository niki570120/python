# %%
import requests,os
from bs4 import BeautifulSoup
from urllib.request import urlopen

url='https://running.biji.co/index.php?q=album&act=photo_list&cid=9261&type=special&subtitle=%E6%B5%AA%E6%BC%AB%E5%8F%B0%E4%B8%89%E7%B7%9A%202021%20%E6%88%80%E6%88%80%E6%A1%90%E8%8A%B1%E5%85%A8%E5%9C%8B%E8%B7%AF%E8%B7%91%E8%B3%BD-%E7%B7%A8%E8%BC%AF%E7%B2%BE%E9%81%B8'
html=requests.get(url)
html.text
# Out:
# '<!DOCTYPE html>\n<html lang="zh-TW">\n\n<head>\n\t<meta charset="utf-8">\n\t<meta http-equiv="cleartype" content="on">\n\t<meta name="viewport" content="width=device-width, height=device-height, initial-scale=1, user-scalable=1, maximum-scale=5.0, user-scalable=yes">\n\t<title>\n\t\t浪漫台三線 2021 戀戀桐花全國路跑賽-編輯精選 | 浪漫台三線 2021 戀戀桐花全國路跑賽-編輯精選 | 相簿 | 運動筆記\t</title>\n\t<!-- facebook-setting -->\n\t\t\t<meta name="description" content="搭配號碼布辨識系統，讓你輕鬆找到自己的賽事相片">\n\t\t<meta name="image" content="https://cdntwrunning.biji.co/600_">\n\t\t<meta property="og:title" content=" -  | 運動筆記" />\n\t\t<meta property="og:site_name" content="運動筆記" />\n\t\t<meta property="og:description" content="搭配號碼布辨識系統，讓你輕鬆找到自己的賽事相片" />\n\t\t<meta property="og:url" content="https://running.biji.co/index.php?q=album&act=photo_list&cid=9261&type=special&subtitle=%E6%B5%AA%E6%BC%AB%E5%8F%B0%E4%B8%89%E7%B7%9A%202021%20%E6%88%80%E6%88%80%E6%A1%90%E8%8A%B1%E5%85%A8%E5%9C%8B%E8%B7%AF%E8%B7%91%E8%B3%BD-%E7%B7%A8%E8%BC%AF%E7%B2%BE%E9%81%B8" />\n\t\t<meta property="og:image" content="https://cdntwrunning.biji.co/600_" />\n\t\t<meta property="og:locale" content="zh_TW" />\n\t\t\t\t\t<meta property="og:type" content="article" />\n\t\t\t<meta property="article:author" content="https://www.facebook.com/SportsNote" />\n\t\t\t<meta property="article:publisher" content="https://www.facebook.com/SportsNote" />\n\t\t\t\t<meta property="fb:app_id" content="230626213615077" />\n\t\t<meta itemprop="name" content=" -  | 運動筆記" />\n\t\t<meta itemprop="image" content="https://cdntwrunning.biji.co/600_" />\n\t\t<meta itemprop="description" content="搭配號碼布辨識系統，讓你輕鬆找到自己的賽事相片" />\n\t\t<!-- favicon Start -->\n\t<link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">\n\t<link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png">\n\t<link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png">\n\t<link rel="manifest" href="/site.webmanifest">\n\t<link rel="mask-icon" href="/safari-pinned-tab.svg" color="#0096ff">\n\t<meta name="application-name" content="運動筆記">\n\t<meta name="msapplication-TileColor" content="#0096ff">\n\t<!-- favicon End -->\n\t<link rel="preconnect" href="https://cdnjs.cloudflare.com" crossorigin>\n\t<link rel="preconnect" href="https://cdntwrunning.biji.co" crossorigin>\n\t<link rel="preload" href="/static/css/computer/main.css?v=1628479633" as="style">\n\t<link href="/static/css/computer/main.css?v=1628479633" rel="stylesheet" media="all">\n\t<link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.6.3/css/font-awesome.min.css" rel="stylesheet">\n\t<link href="https://cdnjs.cloudflare.com/ajax/libs/simple-line-icons/2.4.1/css/simple-line-icons.css" rel="stylesheet" media="all">\n\t<script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/1.11.3/jquery.min.js"></script>\n\t<script src="https://cdnjs.cloudflare.com/ajax/libs/gsap/1.11.4/TweenMax.min.js"></script>\n\t<script src="/static/js/computer/jquery.cookie.js"></script>\n\t<script src="/static/js/jquery.redirect.js"></script>\n\t<script src="/static/js/global.js?v=1619488231"></script>\n\t<script src="/static/js/lazysizes.min.js" async></script>\n\t<!-- 富盈數據start -->\n\t<script async type="text/javascript" charset="utf-8" src="https://a.breaktime.com.tw/js/au.js?spj=N0IxVzJZMURXSVNYNDdISlpDUkhDMTM3"></script>\n\t<!-- 富盈數據end -->\n\t<!-- Google reCAPTCHA -->\n\t<script src=\'https://www.google.com/recaptcha/api.js\' async defer></script>\n\t<!-- <script src="https://cdnjs.cloudflare.com/ajax/libs/socket.io/1.3.7/socket.io.min.js"></script> -->\n\t<!-- Start Alexa Certify Javascript -->\n\t<noscript><img src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=iZrXj1acFH00y6" style="display:none" height="1" width="1" alt="" /></noscript>\n\t<!-- End Alexa Certify Javascript -->\n\t<!-- Begin comScore Tag -->\n\t<script>\n\t\tvar _comscore = _comscore || [];\n\t\t_comscore.push({\n\t\t\tc1: "2",\n\t\t\tc2: "31736412"\n\t\t});\n\t\t(function() {\n\t\t\tvar s = document. ...

# %%
import re
match_list = re.findall(r'photo-img"\ src\s*=\s*"(.+?)"', html.text)

if match_list:
    print(match_list)
# Out:
# ['https://cdntwrunning.biji.co/600_4726563F-9491-2ED8-8AC2-26C6D94B6F00.jpg', 'https://cdntwrunning.biji.co/600_771F2F22-8735-4602-AD13-E99B23BB00F7.jpg', 'https://cdntwrunning.biji.co/600_458F7786-1CF5-452F-2B07-98798C3DD505.jpg', 'https://cdntwrunning.biji.co/600_B28A1426-2827-03C3-EB64-1BB7B78E937C.jpg', 'https://cdntwrunning.biji.co/600_EF813E89-2CEA-8D37-7E92-38B968BB6AD9.jpg', 'https://cdntwrunning.biji.co/600_DD7D2179-00E7-6FE7-2484-6FEDE895FFF5.jpg', 'https://cdntwrunning.biji.co/600_E5013D50-76E4-01DF-AB56-9AE7CC492551.jpg', 'https://cdntwrunning.biji.co/600_5B586255-98CA-81DB-21A6-AD68A5BF895F.jpg', 'https://cdntwrunning.biji.co/600_AB8EF676-584F-26D4-1375-5DE16ED0D5D0.jpg', 'https://cdntwrunning.biji.co/600_5FDFCFBE-7BFB-EC3B-A19E-75B452AC4F3C.jpg', 'https://cdntwrunning.biji.co/600_F47F9E34-243F-82EB-4E08-74316A3DB219.jpg', 'https://cdntwrunning.biji.co/600_86AA28B4-A61F-8B56-7A69-66CD177BF81C.jpg', 'https://cdntwrunning.biji.co/600_5C148722-6BAB-E647-BA82-238E43E57557.jpg', 'https://cdntwrunning.biji.co/600_682AF49F-8C10-2E36-2C70-24B4FEB41B41.jpg', 'https://cdntwrunning.biji.co/600_2F3615E5-74D1-8B28-6261-918D818275D7.jpg', 'https://cdntwrunning.biji.co/600_EB325DC3-5B59-7BF3-9E18-C559507D57DC.jpg', 'https://cdntwrunning.biji.co/600_D8FC9642-8A56-3AC1-EEB8-B38C41DCF4C1.jpg', 'https://cdntwrunning.biji.co/600_40A98A47-E72F-71F7-F6F4-F888729D3D0F.jpg', 'https://cdntwrunning.biji.co/600_AA528B29-AEB3-37D3-AEDA-4FECCAD47687.jpg', 'https://cdntwrunning.biji.co/600_311630E5-638C-88ED-65AF-7E5877702A22.jpg']

# %%
match_list[0]
# Out:
# 'https://cdntwrunning.biji.co/600_4726563F-9491-2ED8-8AC2-26C6D94B6F00.jpg'

# %%
import os

images_dir='./output'
os.makedirs(images_dir, exist_ok=True)

n=0
for src in match_list:
    if src != None and ('.jpg' in src):
        full_path = src
        filename = full_path.split('/')[-1] 
        print(full_path)
       
        try:
            image = urlopen(full_path)
            with open(os.path.join(images_dir,filename),'wb') as f:
                f.write(image.read())
            n+=1
        except:
            print("{} 無法讀取！".format(filename))
        
print("共下載",n,"張圖片")
# Out:
# https://cdntwrunning.biji.co/600_4726563F-9491-2ED8-8AC2-26C6D94B6F00.jpg
# https://cdntwrunning.biji.co/600_771F2F22-8735-4602-AD13-E99B23BB00F7.jpg
# https://cdntwrunning.biji.co/600_458F7786-1CF5-452F-2B07-98798C3DD505.jpg
# https://cdntwrunning.biji.co/600_B28A1426-2827-03C3-EB64-1BB7B78E937C.jpg
# https://cdntwrunning.biji.co/600_EF813E89-2CEA-8D37-7E92-38B968BB6AD9.jpg
# https://cdntwrunning.biji.co/600_DD7D2179-00E7-6FE7-2484-6FEDE895FFF5.jpg
# https://cdntwrunning.biji.co/600_E5013D50-76E4-01DF-AB56-9AE7CC492551.jpg
# https://cdntwrunning.biji.co/600_5B586255-98CA-81DB-21A6-AD68A5BF895F.jpg
# https://cdntwrunning.biji.co/600_AB8EF676-584F-26D4-1375-5DE16ED0D5D0.jpg
# https://cdntwrunning.biji.co/600_5FDFCFBE-7BFB-EC3B-A19E-75B452AC4F3C.jpg
# https://cdntwrunning.biji.co/600_F47F9E34-243F-82EB-4E08-74316A3DB219.jpg
# https://cdntwrunning.biji.co/600_86AA28B4-A61F-8B56-7A69-66CD177BF81C.jpg
# https://cdntwrunning.biji.co/600_5C148722-6BAB-E647-BA82-238E43E57557.jpg
# https://cdntwrunning.biji.co/600_682AF49F-8C10-2E36-2C70-24B4FEB41B41.jpg
# https://cdntwrunning.biji.co/600_2F3615E5-74D1-8B28-6261-918D818275D7.jpg
# https://cdntwrunning.biji.co/600_EB325DC3-5B59-7BF3-9E18-C559507D57DC.jpg
# https://cdntwrunning.biji.co/600_D8FC9642-8A56-3AC1-EEB8-B38C41DCF4C1.jpg
# https://cdntwrunning.biji.co/600_40A98A47-E72F-71F7-F6F4-F888729D3D0F.jpg
# https://cdntwrunning.biji.co/600_AA528B29-AEB3-37D3-AEDA-4FECCAD47687.jpg
# https://cdntwrunning.biji.co/600_311630E5-638C-88ED-65AF-7E5877702A22.jpg
# 共下載 20 張圖片
